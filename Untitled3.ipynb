# %% [markdown]
# <a href="https://colab.research.google.com/github/Garg1510/Fake-news-detection/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
import csv
import random

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

import pprint
import tensorflow.compat.v1 as tf
from tensorflow.python.framework import ops
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
tf.disable_eager_execution()

# Reading the data
data = pd.read_csv("news.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
# encoding the labels
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = .1

# %%
title = []
text = []
labels = []
for x in range(training_size):
	title.append(data['title'][x])
	text.append(data['text'][x])
	labels.append(data['label'][x])

# %%
tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(
	sequences1, padding=padding_type, truncating=trunc_type)
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
embeddings_index = {}
with open('/content/glove.6B.50d (1).txt') as f:
	for line in f:
		values = line.split()
		word = values[0]
		coefs = np.asarray(values[1:], dtype='float32')
		embeddings_index[word] = coefs

# Generating embeddings
embeddings_matrix = np.zeros((vocab_size1+1, embedding_dim))
for word, i in word_index1.items():
	embedding_vector = embeddings_index.get(word)
	if embedding_vector is not None:
		embeddings_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([
	tf.keras.layers.Embedding(vocab_size1+1, embedding_dim,
							input_length=max_length, weights=[
								embeddings_matrix],
							trainable=False),
	tf.keras.layers.Dropout(0.2),
	tf.keras.layers.Conv1D(64, 5, activation='relu'),
	tf.keras.layers.MaxPooling1D(pool_size=4),
	tf.keras.layers.LSTM(64),
	tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',
			optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 54, 50)            377600
#
#  dropout_2 (Dropout)         (None, 54, 50)            0
#
#  conv1d_2 (Conv1D)           (None, 50, 64)            16064
#
#  max_pooling1d_2 (MaxPooling  (None, 12, 64)           0
#  1D)
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 426,753
# Trainable params: 49,153
# Non-trainable params: 377,600
# _________________________________________________________________

# %%
num_epochs = 50

training_padded = np.array(training_sequences1)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences1)
testing_labels = np.array(test_labels)

history = model.fit(training_padded, training_labels,
					epochs=num_epochs,
					validation_data=(testing_padded,
									testing_labels),
					verbose=2)
# Out:
# Train on 2700 samples, validate on 300 samples
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2700/2700 - 4s - loss: 0.6376 - accuracy: 0.6200 - val_loss: 0.5516 - val_accuracy: 0.7033 - 4s/epoch - 1ms/sample
# Epoch 2/50
# 2700/2700 - 2s - loss: 0.5650 - accuracy: 0.7015 - val_loss: 0.5333 - val_accuracy: 0.7000 - 2s/epoch - 783us/sample
# Epoch 3/50
# 2700/2700 - 2s - loss: 0.5197 - accuracy: 0.7378 - val_loss: 0.5076 - val_accuracy: 0.7367 - 2s/epoch - 779us/sample
# Epoch 4/50
# 2700/2700 - 2s - loss: 0.4680 - accuracy: 0.7741 - val_loss: 0.4799 - val_accuracy: 0.7467 - 2s/epoch - 775us/sample
# Epoch 5/50
# 2700/2700 - 3s - loss: 0.4341 - accuracy: 0.7956 - val_loss: 0.4869 - val_accuracy: 0.7400 - 3s/epoch - 978us/sample
# Epoch 6/50
# 2700/2700 - 3s - loss: 0.4033 - accuracy: 0.8122 - val_loss: 0.4891 - val_accuracy: 0.7667 - 3s/epoch - 1ms/sample
# Epoch 7/50
# 2700/2700 - 2s - loss: 0.3505 - accuracy: 0.8463 - val_loss: 0.4830 - val_accuracy: 0.7633 - 2s/epoch - 776us/sample
# Epoch 8/50
# 2700/2700 - 2s - loss: 0.3114 - accuracy: 0.8644 - val_loss: 0.5379 - val_accuracy: 0.7333 - 2s/epoch - 794us/sample
# Epoch 9/50
# 2700/2700 - 2s - loss: 0.2983 - accuracy: 0.8767 - val_loss: 0.5011 - val_accuracy: 0.7867 - 2s/epoch - 783us/sample
# Epoch 10/50
# 2700/2700 - 2s - loss: 0.2603 - accuracy: 0.8930 - val_loss: 0.5336 - val_accuracy: 0.7267 - 2s/epoch - 780us/sample
# Epoch 11/50
# 2700/2700 - 3s - loss: 0.2509 - accuracy: 0.8974 - val_loss: 0.4956 - val_accuracy: 0.7700 - 3s/epoch - 1ms/sample
# Epoch 12/50
# 2700/2700 - 2s - loss: 0.2197 - accuracy: 0.9048 - val_loss: 0.6413 - val_accuracy: 0.7533 - 2s/epoch - 776us/sample
# Epoch 13/50
# 2700/2700 - 2s - loss: 0.2195 - accuracy: 0.9137 - val_loss: 0.5332 - val_accuracy: 0.7867 - 2s/epoch - 769us/sample
# Epoch 14/50
# 2700/2700 - 2s - loss: 0.1804 - accuracy: 0.9259 - val_loss: 0.5491 - val_accuracy: 0.7800 - 2s/epoch - 780us/sample
# Epoch 15/50
# 2700/2700 - 2s - loss: 0.1729 - accuracy: 0.9322 - val_loss: 0.5173 - val_accuracy: 0.8133 - 2s/epoch - 794us/sample
# Epoch 16/50
# 2700/2700 - 3s - loss: 0.1887 - accuracy: 0.9270 - val_loss: 0.5743 - val_accuracy: 0.7767 - 3s/epoch - 1ms/sample
# Epoch 17/50
# 2700/2700 - 3s - loss: 0.1570 - accuracy: 0.9419 - val_loss: 0.6221 - val_accuracy: 0.7567 - 3s/epoch - 1ms/sample
# Epoch 18/50
# 2700/2700 - 2s - loss: 0.1463 - accuracy: 0.9419 - val_loss: 0.5644 - val_accuracy: 0.7700 - 2s/epoch - 778us/sample
# Epoch 19/50
# 2700/2700 - 2s - loss: 0.1398 - accuracy: 0.9426 - val_loss: 0.7966 - val_accuracy: 0.7467 - 2s/epoch - 790us/sample
# Epoch 20/50
# 2700/2700 - 2s - loss: 0.1336 - accuracy: 0.9485 - val_loss: 0.7341 - val_accuracy: 0.7767 - 2s/epoch - 804us/sample
# Epoch 21/50
# 2700/2700 - 2s - loss: 0.1311 - accuracy: 0.9485 - val_loss: 0.6266 - val_accuracy: 0.7933 - 2s/epoch - 796us/sample
# Epoch 22/50
# 2700/2700 - 3s - loss: 0.1465 - accuracy: 0.9411 - val_loss: 0.5485 - val_accuracy: 0.7800 - 3s/epoch - 1ms/sample
# Epoch 23/50
# 2700/2700 - 2s - loss: 0.1325 - accuracy: 0.9522 - val_loss: 0.6703 - val_accuracy: 0.7533 - 2s/epoch - 774us/sample
# Epoch 24/50
# 2700/2700 - 2s - loss: 0.1055 - accuracy: 0.9567 - val_loss: 0.8176 - val_accuracy: 0.7433 - 2s/epoch - 782us/sample
# Epoch 25/50
# 2700/2700 - 2s - loss: 0.0944 - accuracy: 0.9633 - val_loss: 0.8066 - val_accuracy: 0.7433 - 2s/epoch - 781us/sample
# Epoch 26/50
# 2700/2700 - 2s - loss: 0.1171 - accuracy: 0.9596 - val_loss: 0.8306 - val_accuracy: 0.7333 - 2s/epoch - 782us/sample
# Epoch 27/50
# 2700/2700 - 3s - loss: 0.0939 - accuracy: 0.9630 - val_loss: 0.7608 - val_accuracy: 0.7667 - 3s/epoch - 1ms/sample
# Epoch 28/50
# 2700/2700 - 2s - loss: 0.1079 - accuracy: 0.9585 - val_loss: 0.6671 - val_accuracy: 0.7500 - 2s/epoch - 892us/sample
# Epoch 29/50
# 2700/2700 - 2s - loss: 0.0956 - accuracy: 0.9630 - val_loss: 0.6836 - val_accuracy: 0.7800 - 2s/epoch - 791us/sample
# Epoch 30/50
# 2700/2700 - 2s - loss: 0.0917 - accuracy: 0.9633 - val_loss: 0.7693 - val_accuracy: 0.7600 - 2s/epoch - 779us/sample
# Epoch 31/50
# 2700/2700 - 2s - loss: 0.0864 - accuracy: 0.9674 - val_loss: 0.7615 - val_accuracy: 0.7700 - 2s/epoch - 764us/sample
# Epoch 32/50
# 2700/2700 - 2s - loss: 0.0868 - accuracy: 0.9696 - val_loss: 0.8035 - val_accuracy: 0.7600 - 2s/epoch - 845us/sample
# Epoch 33/50
# 2700/2700 - 3s - loss: 0.0853 - accuracy: 0.9674 - val_loss: 0.8526 - val_accuracy: 0.7733 - 3s/epoch - 1ms/sample
# Epoch 34/50
# 2700/2700 - 2s - loss: 0.0728 - accuracy: 0.9733 - val_loss: 0.9033 - val_accuracy: 0.7567 - 2s/epoch - 819us/sample
# Epoch 35/50
# 2700/2700 - 2s - loss: 0.0836 - accuracy: 0.9711 - val_loss: 0.7527 - val_accuracy: 0.7533 - 2s/epoch - 778us/sample
# Epoch 36/50
# 2700/2700 - 2s - loss: 0.0889 - accuracy: 0.9626 - val_loss: 0.8429 - val_accuracy: 0.7633 - 2s/epoch - 784us/sample
# Epoch 37/50
# 2700/2700 - 2s - loss: 0.0845 - accuracy: 0.9648 - val_loss: 0.8263 - val_accuracy: 0.7600 - 2s/epoch - 781us/sample
# Epoch 38/50
# 2700/2700 - 3s - loss: 0.0884 - accuracy: 0.9678 - val_loss: 0.7808 - val_accuracy: 0.7867 - 3s/epoch - 1ms/sample
# Epoch 39/50
# 2700/2700 - 2s - loss: 0.0554 - accuracy: 0.9793 - val_loss: 0.9489 - val_accuracy: 0.7767 - 2s/epoch - 812us/sample
# Epoch 40/50
# 2700/2700 - 2s - loss: 0.0871 - accuracy: 0.9696 - val_loss: 0.8172 - val_accuracy: 0.7600 - 2s/epoch - 794us/sample
# Epoch 41/50
# 2700/2700 - 2s - loss: 0.0950 - accuracy: 0.9648 - val_loss: 0.8262 - val_accuracy: 0.7733 - 2s/epoch - 780us/sample
# Epoch 42/50
# 2700/2700 - 2s - loss: 0.0741 - accuracy: 0.9707 - val_loss: 0.7989 - val_accuracy: 0.7633 - 2s/epoch - 791us/sample
# Epoch 43/50
# 2700/2700 - 3s - loss: 0.0573 - accuracy: 0.9789 - val_loss: 0.9486 - val_accuracy: 0.7667 - 3s/epoch - 954us/sample
# Epoch 44/50
# 2700/2700 - 3s - loss: 0.0679 - accuracy: 0.9737 - val_loss: 0.7832 - val_accuracy: 0.7467 - 3s/epoch - 1ms/sample
# Epoch 45/50
# 2700/2700 - 2s - loss: 0.0572 - accuracy: 0.9770 - val_loss: 0.9474 - val_accuracy: 0.7700 - 2s/epoch - 773us/sample
# Epoch 46/50
# 2700/2700 - 2s - loss: 0.0727 - accuracy: 0.9741 - val_loss: 0.9260 - val_accuracy: 0.7567 - 2s/epoch - 770us/sample
# Epoch 47/50
# 2700/2700 - 2s - loss: 0.0602 - accuracy: 0.9793 - val_loss: 0.8752 - val_accuracy: 0.7633 - 2s/epoch - 773us/sample
# Epoch 48/50
# 2700/2700 - 2s - loss: 0.0927 - accuracy: 0.9693 - val_loss: 0.6249 - val_accuracy: 0.7467 - 2s/epoch - 777us/sample
# Epoch 49/50
# 2700/2700 - 3s - loss: 0.0627 - accuracy: 0.9804 - val_loss: 0.8706 - val_accuracy: 0.7700 - 3s/epoch - 1ms/sample
# Epoch 50/50
# 2700/2700 - 2s - loss: 0.0546 - accuracy: 0.9796 - val_loss: 0.8189 - val_accuracy: 0.7600 - 2s/epoch - 786us/sample

# %%
# sample text to check if fake or not
X = "Karry to go to France in gesture of sympathy"

# detection
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
						padding=padding_type,
						truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
	print("This news is True")
else:
	print("This news is false")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# This news is True
